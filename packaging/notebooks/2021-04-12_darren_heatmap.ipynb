# %%
import xarray as xr

# %%
xr.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.7.2 (default, Dec 29 2018, 06:19:36)
# [GCC 7.3.0]
# python-bits: 64
# OS: Linux
# OS-release: 4.4.0-179-generic
# machine: x86_64
# processor: x86_64
# byteorder: little
# LC_ALL: None
# LANG: en_US.UTF-8
# LOCALE: en_US.UTF-8
# libhdf5: 1.10.2
# libnetcdf: 4.4.1.1
#
# xarray: 0.12.0
# pandas: 0.24.0
# numpy: 1.15.4
# scipy: 1.2.0
# netCDF4: 1.4.2
# pydap: None
# h5netcdf: None
# h5py: None
# Nio: None
# zarr: None
# cftime: 1.0.3.4
# nc_time_axis: None
# PseudonetCDF: None
# rasterio: None
# cfgrib: None
# iris: None
# bottleneck: None
# dask: None
# distributed: None
# matplotlib: None
# cartopy: None
# seaborn: None
# setuptools: 40.6.3
# pip: 18.1
# conda: None
# pytest: 4.2.0
# IPython: 7.2.0
# sphinx: None

# %%
class FooSub(xr.DataArray):

# %%
from brainio_collection import list_stimulus_sets, list_assemblies, get_stimulus_set, get_assembly

# %%
list_assemblies()
# Out:
# array(['dicarlo.MajajHong2015', 'gallant.David2004',
#        'dicarlo.MajajHong2015.temporal', 'tolias.Cadena2017',
#        'movshon.FreemanZiemba2013.noaperture',
#        'dicarlo.Rajalingham2018.public',
#        'dicarlo.Rajalingham2018.private', 'dicarlo.Kar2019',
#        'dicarlo.MajajHong2015.temporal-10ms', 'dicarlo.Kar2018hvm',
#        'dicarlo.Kar2018cocogray', 'dicarlo.MajajHong2015.public',
#        'dicarlo.MajajHong2015.private',
#        'dicarlo.MajajHong2015.temporal.public',
#        'dicarlo.MajajHong2015.temporal.private',
#        'movshon.FreemanZiemba2013.noaperture.public',
#        'movshon.FreemanZiemba2013.noaperture.private',
#        'klab.Zhang2018search_obj_array',
#        'movshon.FreemanZiemba2013.public',
#        'movshon.FreemanZiemba2013.private', 'movshon.FreemanZiemba2013',
#        'dicarlo.SanghaviMurty2020', 'dicarlo.SanghaviJozwik2020',
#        'dicarlo.Sanghavi2020', 'dicarlo.SanghaviMurty2020THINGS1',
# ...

# %%
darren = get_assembly("dicarlo.Seibert2019")
darren
# Out:
# <xarray.NeuronRecordingAssembly 'dicarlo.Seibert2019' (neuroid: 258, presentation: 286080, time_bin: 1)>
# array([[[ 1.33558   ],
#         [ 1.67803641],
#         [ 0.99312359],
#         ...,
#         [        nan],
#         [        nan],
#         [        nan]],
#
#        [[-1.39968976],
#         [ 0.49178289],
#         [ 0.11348836],
#         ...,
#         [        nan],
#         [        nan],
#         [        nan]],
#
#        [[ 0.05594569],
#         [ 2.85322997],
#         [ 0.33567411],
#         ...,
# ...
#         ...,
#         [        nan],
#         [        nan],
#         [        nan]],
#
#        [[-1.23115138],
#         [-0.73869083],
#         [-0.73869083],
#         ...,
#         [        nan],
#         [        nan],
#         [        nan]],
#
#        [[-1.19751431],
#         [ 0.86716554],
#         [ 0.0412936 ],
#         ...,
#         [        nan],
#         [        nan],
#         [        nan]]])
# Coordinates:
# ...

# %%
from matplotlib import pyplot as plt

# %%
fig, ax = plt.subplots()

# %%
ax.imshow(darren[:, 150000:152500, :].squeeze().transpose())
fig

# %%
fig.set_size_inches(15,25)
ax.get_cmap().set_bad(color="black")
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-a89ee2b7feb0> in <module>
#       1 fig.set_size_inches(15,25)
# ----> 2 ax.get_cmap().set_bad(color="black")
#       3 fig
#
# AttributeError: 'AxesSubplot' object has no attribute 'get_cmap'

# %%
ax.get_children()[-2].get_cmap().set_bad(color="black")
# Out:
# /braintree/home/jjpr/anaconda3/envs/brainio/lib/python3.7/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   """Entry point for launching an IPython kernel.

# %%
fig

# %%
ax.get_children()
# Out:
# ...
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
# ...

# %%
ax.images

# %%
im = ax.images[-1]
im

# %%
im.

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit',
#  'xr']
