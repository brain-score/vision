# %%
import torch

# Path to the .pth file
file_path = './ReAlnet01_best_model_params.pth'

# Load the .pth file
data = torch.load(file_path, map_location='cpu')

# Print the contents of the .pth file
print(data.keys())

data2 = torch.load('cornet_s-1d3f7974.pth', map_location='cpu')
print(data2['state_dict'].keys())
# Out:
# odict_keys(['realnet.module.V1.conv1.weight', 'realnet.module.V1.norm1.weight', 'realnet.module.V1.norm1.bias', 'realnet.module.V1.norm1.running_mean', 'realnet.module.V1.norm1.running_var', 'realnet.module.V1.norm1.num_batches_tracked', 'realnet.module.V1.conv2.weight', 'realnet.module.V1.norm2.weight', 'realnet.module.V1.norm2.bias', 'realnet.module.V1.norm2.running_mean', 'realnet.module.V1.norm2.running_var', 'realnet.module.V1.norm2.num_batches_tracked', 'realnet.module.V2.conv_input.weight', 'realnet.module.V2.skip.weight', 'realnet.module.V2.norm_skip.weight', 'realnet.module.V2.norm_skip.bias', 'realnet.module.V2.norm_skip.running_mean', 'realnet.module.V2.norm_skip.running_var', 'realnet.module.V2.norm_skip.num_batches_tracked', 'realnet.module.V2.conv1.weight', 'realnet.module.V2.conv2.weight', 'realnet.module.V2.conv3.weight', 'realnet.module.V2.norm1_0.weight', 'realnet.module.V2.norm1_0.bias', 'realnet.module.V2.norm1_0.running_mean', 'realnet.module.V2.norm1_0.running_v
# ...
